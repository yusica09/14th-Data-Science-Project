# %% [markdown]
# <a href="https://colab.research.google.com/github/yusica09/14th-Data-Science-Projects/blob/main/2%EC%A3%BC%EC%B0%A8/2%EC%A3%BC%EC%B0%A8_%EA%B0%95%EC%9D%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## 피마인디언 당뇨병 데이터
#
# * 캐글에서 제공하는 피마인디언 당뇨병 데이터 사용

# %% [markdown]
# ### 당뇨셋 데이터 구성
#
# * Pregnancies : 임신 횟수
# * Glucose : 2시간 동안의 경구 포도당 내성 검사에서 혈장 포도당 농도
# * BloodPressure : 이완기 혈압 (mm Hg)
# * SkinThickness : 삼두근 피부 주름 두께 (mm), 체지방을 추정하는데 사용되는 값
# * Insulin : 2시간 혈청 인슐린 (mu U / ml)
# * BMI : 체질량 지수 (체중kg / 키(m)^2)
# * DiabetesPedigreeFunction : 당뇨병 혈통 기능
# * Age : 나이
# * Outcome : 768개 중에 268개의 결과 클래스 변수(0 또는 1)는 1이고 나머지는 0입니다.

# %% [markdown]
# ## 라이브러리 로드

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## 데이터 로드

# %%
df = pd.read_csv("data/diabetes.csv")
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# info로 데이터타입, 결측치, 메모리 사용량 등의 정보 보기
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# 결측치 보기
df_null = df.isnull()
df_null.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0        False    False          False          False    False  False
# 1        False    False          False          False    False  False
# 2        False    False          False          False    False  False
# 3        False    False          False          False    False  False
# 4        False    False          False          False    False  False
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     False  False    False
# 1                     False  False    False
# 2                     False  False    False
# 3                     False  False    False
# 4                     False  False    False

# %%
# 결측치 총 수 보기
df_null.sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# * 결측치가 없어서 위의 df_null.head() 에서 False만 나오며,
#
#     df_null.sum() 은 0이 나온다.

# %%
# 수치데이터에 대한 요약 보기

df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.describe(include='number')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# 마지막의 Outcome 은 label 값임에 유의하고
# 학습과 예측에 사용할 컬럼 만들기
# feature_columns 라는 변수에 담기

feature_columns = df.columns[:-1].tolist()
feature_columns
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %% [markdown]
# ## 결측치 시각화
#
# - 값을 요약해보면 최솟값이 0으로 나오는 값들 존재
#
#   ex) 인슐린, 혈압 등의 경우 결측치 의심
#
#   -> 결측치로 처리하고 시각화해보기!

# %%
cols = feature_columns[1:]
cols
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
# 결측치 여부를 나타내는 데이터프레임
# 0 -> NaN
df_null = df[cols].replace(0, np.nan)
df_null = df_null.isnull()
df_null.sum()
# Out:
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64

# %%
df_null.mean() * 100
# Out:
# Glucose                      0.651042
# BloodPressure                4.557292
# SkinThickness               29.557292
# Insulin                     48.697917
# BMI                          1.432292
# DiabetesPedigreeFunction     0.000000
# Age                          0.000000
# dtype: float64

# %%
# 결측치의 갯수를 막대 그래프로 시각화
df_null.sum().plot.barh()
# Out:
# <AxesSubplot:>

# %%
# 결측치를 heatmap 으로 시각화
plt.figure(figsize=(15,4))
# cmap="Greys" 으로 인해 결측치만 흑색으로 나타남
# 결측치만 하얗게 보고싶다면 cmap="Greys_r"
sns.heatmap(df_null, cmap="Greys")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 정답값
# - = target , label

# %%
# 정답값인 Outcome의 개수 확인
# 1이 발병
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
# Outcome 의 비율 확인
df["Outcome"].value_counts(normalize=True)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Outcome, dtype: float64

# %%
# 다른 변수와 함께 보기
# 임신횟수와 정답값을 비교해보기
# "Pregnancies"를 groupby 로 그룹화해서 Outcome 비율 구하기

# df.groupby(["index"])["value"]

df.groupby(["Pregnancies"])["Outcome"].mean()
# Out:
# Pregnancies
# 0     0.342342
# 1     0.214815
# 2     0.184466
# 3     0.360000
# 4     0.338235
# 5     0.368421
# 6     0.320000
# 7     0.555556
# 8     0.578947
# 9     0.642857
# 10    0.416667
# 11    0.636364
# 12    0.444444
# 13    0.500000
# 14    1.000000
# 15    1.000000
# 17    1.000000
# Name: Outcome, dtype: float64

# %%
# 평균값과 함께 count 값 같이 보기
df.groupby(["Pregnancies"])["Outcome"].agg(["mean","count"])
# Out:
#                  mean  count
# Pregnancies
# 0            0.342342    111
# 1            0.214815    135
# 2            0.184466    103
# 3            0.360000     75
# 4            0.338235     68
# 5            0.368421     57
# 6            0.320000     50
# 7            0.555556     45
# 8            0.578947     38
# 9            0.642857     28
# 10           0.416667     24
# 11           0.636364     11
# 12           0.444444      9
# 13           0.500000     10
# 14           1.000000      2
# 15           1.000000      1
# 17           1.000000      1

# %%
# 위의 결과에서 Pregnancies를 컬럼값으로 추가하고 싶은 경우, .reset_index() 이용

df_po = df.groupby(["Pregnancies"])["Outcome"].agg(["mean","count"]).reset_index()
df_po
# Out:
#     Pregnancies      mean  count
# 0             0  0.342342    111
# 1             1  0.214815    135
# 2             2  0.184466    103
# 3             3  0.360000     75
# 4             4  0.338235     68
# 5             5  0.368421     57
# 6             6  0.320000     50
# 7             7  0.555556     45
# 8             8  0.578947     38
# 9             9  0.642857     28
# 10           10  0.416667     24
# 11           11  0.636364     11
# 12           12  0.444444      9
# 13           13  0.500000     10
# 14           14  1.000000      2
# 15           15  1.000000      1
# 16           17  1.000000      1

# %%
# 임신횟수에 따른 당뇨병 발병 비율
df_po.plot()
# Out:
# <AxesSubplot:>

# %%
df_po["mean"].plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## count plot

# %%
# 당뇨병 발병 빈도수 비교
sns.countplot(data=df, x="Outcome")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
# 임신횟수에 따른 당뇨병 발병 빈도수
sns.countplot(data=df, x="Pregnancies")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='count'>

# %%
sns.countplot(data=df, x="Pregnancies", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='count'>

# %% [markdown]
# * 위의 plot에서 봤을 때 11회 이상부터는 표본이 적어 overfitting 가능성이 크다
#
#     => 따라서 '범주화' 해서 표현하기도 함

# %%
# 임신횟수의 많고 적음에 따라 Pregnancies_high 변수
df["Pregnancies_high"] = df["Pregnancies"] > 6

# 여러개의 df를 같이 보고 싶을 땐, list를 이용하기
df[["Pregnancies","Pregnancies_high"]].head()
# Out:
#    Pregnancies  Pregnancies_high
# 0            6             False
# 1            1             False
# 2            8              True
# 3            1             False
# 4            0             False

# %%
# Pregnancies_high 변수의 빈도수를 countplot 으로 그리고
# Outcome 값에 따라 다른 색상으로 표현

sns.countplot(data=df, x="Pregnancies_high", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies_high', ylabel='count'>

# %% [markdown]
# * 위처럼 연속된 수치데이터는 범주화해서 표현하기도 하는데,
#
#     이것을 '원핫 인코딩' 이라고 한다.

# %% [markdown]
# ## bar plot
#
# - 기본 설정으로 시각화하면 y축에는 평균을 추정해서 그린다.

# %%
# 당뇨병 발병에 따른 BMI 수치 비교

sns.barplot(data=df, x="Outcome", y="BMI")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='BMI'>

# %%
# 당뇨병 발병에 따른 포도당수치 비교

sns.barplot(data=df, x="Outcome", y="Glucose")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Glucose'>

# %%
# Insulin 수치가 0 이상인 관측치에 대해 당뇨병 발병 비교

sns.barplot(data=df, x="Outcome", y="Insulin")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Insulin'>

# %% [markdown]
# * 위에서 검정색 막대는 신뢰구간을 의미 (파라미터: ci, 기본값 95)

# %%
# 임신횟수에 대해서 당뇨병 발병 비율 비교

sns.barplot(data=df, x="Pregnancies", y="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Outcome'>

# %%
# 임신횟수에 따른 포도당 수치를 당뇨병 발병여부에 따라 시각화

sns.barplot(data=df, x="Pregnancies", y="Glucose", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Glucose'>

# %%
# 임신횟수에 따른 BMI를 당뇨병 발병여부에 따라 시각화

sns.barplot(data=df, x="Pregnancies", y="BMI", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='BMI'>

# %%
# 임신횟수에 따른 인슐린 수치를 당뇨병 발병여부에 따라 시각화

sns.barplot(data=df, x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# ## box plot

# %%
# 임신횟수에 따른 인슐린 수치를 당뇨병 발병여부에 따라 시각화
# 인슐린 수치에는 결측치가 많이 때문에 0보다 큰 값에 대해서만

sns.boxplot(data=df[df["Insulin"]>0],
            x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# ## violin plot

# %%
# 위의 그래프를 violin plot으로 시각화
plt.figure(figsize=(15,4))
sns.violinplot(data=df[df["Insulin"]>0],
            x="Pregnancies", y="Insulin",
            hue="Outcome", split=True)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# ## swarm plot

# %%
# 위의 그래프를 swarm plot으로 시각화

plt.figure(figsize=(15,4))
sns.swarmplot(data=df[df["Insulin"]>0],
            x="Pregnancies", y="Insulin",
            hue="Outcome", size=3)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# ## dist plot

# %%
df_0 = df[df["Outcome"] == 0]
df_1 = df[df["Outcome"] == 1]
df_0.shape, df_1.shape
# Out:
# ((500, 10), (268, 10))

# %%
# 임신횟수에 따른 당뇨병 발병 여부 시각화

# import warnings
# warnings.filterwarnings("ignore", category=FutureWarning)

sns.distplot(df_0["Pregnancies"]) # 파랑
sns.distplot(df_1["Pregnancies"]) # 주황
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Density'>

# %%
# 나이에 따른 당뇨병 발병 여부 시각화

sns.distplot(df_0["Age"], hist=False, rug=True, label=0)
sns.distplot(df_1["Age"], hist=False, rug=True, label=1)

plt.legend()

# %% [markdown]
# ## Subplots

# %% [markdown]
# ### pandas 를 통한 histplot 그리기
# * pandas를 사용하면 모든 변수에 대한 서브플롯을 한번에 그려준다.

# %%
# hist는 불리언 지원 x, 따라서 숫자형태로 바꿔주기
df["Pregnancies_high"] = df["Pregnancies_high"].astype(int)
df["Pregnancies_high"]
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 763    1
# 764    0
# 765    0
# 766    0
# 767    0
# Name: Pregnancies_high, Length: 768, dtype: int64

# %%
# bins = 막대 개수
h = df.hist(figsize=(15,15), bins=20)

# %% [markdown]
# ### 반복문을 통한 서브플롯 그리기

# %% [markdown]
# #### distplot

# %%
# 컬럼의 수 만큼 for 문을 만들어서 서브플롯으로 시각화
col_num = df.columns.shape
col_num
# Out:
# (10,)

# %%
cols = df.columns[:-1].tolist()
cols
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
# distplot 으로 서브플롯을 그리기
# 백지상태
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15,15))
# 플롯그리고 ax=axes[][]로 위치 설정
# sns.distplot(df["Outcome"], ax=axes[0][0])

for i, col_name in enumerate(cols):
    row = i // 3
    col = i % 3
    print(i, col_name, row, col)
    sns.distplot(df[col_name], ax=axes[row][col])
# Out:
# 0 Pregnancies 0 0
# 1 Glucose 0 1
# 2 BloodPressure 0 2
# 3 SkinThickness 1 0
# 4 Insulin 1 1
# 5 BMI 1 2
# 6 DiabetesPedigreeFunction 2 0
# 7 Age 2 1
# 8 Outcome 2 2

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15,15))

for i, col_name in enumerate(cols[:-1]):
    row = i // 2
    col = i % 2
    print(i, col_name, row, col)
    # outcome 에 따라 다르게 그리기
    sns.distplot(df_0[col_name], ax=axes[row][col])
    sns.distplot(df_1[col_name], ax=axes[row][col])
# Out:
# 0 Pregnancies 0 0
# 1 Glucose 0 1
# 2 BloodPressure 1 0
# 3 SkinThickness 1 1
# 4 Insulin 2 0
# 5 BMI 2 1
# 6 DiabetesPedigreeFunction 3 0
# 7 Age 3 1

# %% [markdown]
# #### violinplot

# %%
# violinplot 으로 서브플롯 그리기

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15,15))

for i, col_name in enumerate(cols[:-1]):
    row = i // 2
    col = i % 2
    sns.violinplot(data=df, x="Outcome", y=col_name, ax=axes[row][col])

# %% [markdown]
# #### lmplot
# * 상관계수가 높은 두 변수에 대해 시각화

# %%
# Glucose 와 Insulin 을 Outcome 으로 구분

sns.regplot(data=df, x="Glucose", y="Insulin")
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Insulin'>

# %%
# regplot은 hue를 지원하지 않기 때문에 hue를 이용하려면 lmplot 이용

sns.lmplot(data=df, x="Glucose", y="Insulin", hue="Outcome")

# %%
# Insulin 수치가 0 이상인 데이터로만 그리기

sns.lmplot(data=df[df["Insulin"] > 0], x="Glucose", y="Insulin", hue="Outcome")

# %% [markdown]
# #### pairplot

# %%
# PairGrid 를 통해 모든 변수에 대해 Outcome 에 따른 scatterplot 그리기
# kind 의 기본값은 scatter
sns.pairplot(df, kind="reg")

# %%
g = sns.PairGrid(df, hue="Outcome")
g.map(plt.scatter)

# %% [markdown]
# ## 상관 분석
# * 상관 분석은 두 변수 간의 선형적/비선형적 관계를 갖고 있는 지를 분석하는 방법
# * 수치가 1에 가까우면 강한 양의 상관관계이며 -1에 가까우면 강한 음의 상관관계입니다. 0이면 상관관계가 없습니다.

# %%
# 상관계수 구하기

df_corr = df.corr()
df_corr.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_afdf9_row0_col0,#T_afdf9_row1_col1,#T_afdf9_row2_col2,#T_afdf9_row3_col3,#T_afdf9_row4_col4,#T_afdf9_row5_col5,#T_afdf9_row6_col6,#T_afdf9_row7_col7,#T_afdf9_row8_col8,#T_afdf9_row9_col9{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_afdf9_row0_col1,#T_afdf9_row9_col3{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_afdf9_row0_col2,#T_afdf9_row2_col1,#T_afdf9_row9_col1{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_afdf9_row0_col3,#T_afdf9_row7_col4{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_afdf9_row0_col4,#T_afdf9_row0_col5,#T_afdf9_row0_col6,#T_afdf9_row2_col8,#T_afdf9_row3_col0,#T_afdf9_row3_col1,#T_afdf9_row3_col7,#T_afdf9_row3_col9,#T_afdf9_row4_col9,#T_afdf9_row6_col2,#T_afdf9_row7_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_afdf9_row0_col7{
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_afdf9_row0_col8,#T_afdf9_row1_col6{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_afdf9_row0_col9{
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }#T_afdf9_row1_col0{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_afdf9_row1_col2,#T_afdf9_row6_col8{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_afdf9_row1_col3{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_afdf9_row1_col4{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_afdf9_row1_col5,#T_afdf9_row3_col6,#T_afdf9_row4_col6{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_afdf9_row1_col7{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_afdf9_row1_col8{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_afdf9_row1_col9{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_afdf9_row2_col0,#T_afdf9_row7_col2{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_afdf9_row2_col3{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_afdf9_row2_col4,#T_afdf9_row2_col9{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_afdf9_row2_col5,#T_afdf9_row6_col3{
#             background-color:  #cacee5;
#             color:  #000000;
#         }#T_afdf9_row2_col6{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_afdf9_row2_col7{
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }#T_afdf9_row3_col2,#T_afdf9_row5_col1{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_afdf9_row3_col4{
#             background-color:  #7eadd1;
#             color:  #000000;
#         }#T_afdf9_row3_col5{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_afdf9_row3_col8{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_afdf9_row4_col0{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_afdf9_row4_col1{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_afdf9_row4_col2,#T_afdf9_row6_col0,#T_afdf9_row6_col9,#T_afdf9_row9_col6{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_afdf9_row4_col3{
#             background-color:  #76aad0;
#             color:  #000000;
#         }#T_afdf9_row4_col5{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_afdf9_row4_col7,#T_afdf9_row7_col6{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_afdf9_row4_col8,#T_afdf9_row5_col9{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_afdf9_row5_col0{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_afdf9_row5_col2,#T_afdf9_row5_col4{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_afdf9_row5_col3{
#             background-color:  #86b0d3;
#             color:  #000000;
#         }#T_afdf9_row5_col6,#T_afdf9_row8_col3{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_afdf9_row5_col7{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_afdf9_row5_col8{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_afdf9_row6_col1,#T_afdf9_row9_col2{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_afdf9_row6_col4{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_afdf9_row6_col5{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_afdf9_row6_col7{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_afdf9_row7_col0{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_afdf9_row7_col1{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_afdf9_row7_col5{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_afdf9_row7_col8,#T_afdf9_row9_col8{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_afdf9_row7_col9{
#             background-color:  #79abd0;
#             color:  #000000;
#         }#T_afdf9_row8_col0,#T_afdf9_row8_col5{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_afdf9_row8_col1{
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }#T_afdf9_row8_col2{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_afdf9_row8_col4{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_afdf9_row8_col6{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_afdf9_row8_col7{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_afdf9_row8_col9{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_afdf9_row9_col0{
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }#T_afdf9_row9_col4{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_afdf9_row9_col5{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_afdf9_row9_col7{
#             background-color:  #69a5cc;
#             color:  #000000;
#         }</style><table id="T_afdf9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pregnancies</th>        <th class="col_heading level0 col1" >Glucose</th>        <th class="col_heading level0 col2" >BloodPressure</th>        <th class="col_heading level0 col3" >SkinThickness</th>        <th class="col_heading level0 col4" >Insulin</th>        <th class="col_heading level0 col5" >BMI</th>        <th class="col_heading level0 col6" >DiabetesPedigreeFunction</th>        <th class="col_heading level0 col7" >Age</th>        <th class="col_heading level0 col8" >Outcome</th>        <th class="col_heading level0 col9" >Pregnancies_high</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_afdf9_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#                         <td id="T_afdf9_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_afdf9_row0_col1" class="data row0 col1" >0.129459</td>
#                         <td id="T_afdf9_row0_col2" class="data row0 col2" >0.141282</td>
#                         <td id="T_afdf9_row0_col3" class="data row0 col3" >-0.081672</td>
#                         <td id="T_afdf9_row0_col4" class="data row0 col4" >-0.073535</td>
#                         <td id="T_afdf9_row0_col5" class="data row0 col5" >0.017683</td>
#                         <td id="T_afdf9_

# %%
# 위에서 구한 상관계수를 heatmap 으로 시각화
plt.figure(figsize=(12,8))
sns.heatmap(df_corr, annot=True, vmax=1, vmin=-1, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
# 정답값인 Outcome을 제외하고 feature로 사용할 컬럼들에 대해 0을 결측치로 만들기

df_matrix = df.iloc[:,:-2].replace(0, np.nan)
df_matrix["Outcome"] = df["Outcome"]
df_matrix.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      NaN  33.6
# 1          1.0     85.0           66.0           29.0      NaN  26.6
# 2          8.0    183.0           64.0            NaN      NaN  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_corr_1 = df_matrix.corr()
df_corr_1.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_79f48_row0_col0,#T_79f48_row1_col1,#T_79f48_row2_col2,#T_79f48_row3_col3,#T_79f48_row4_col4,#T_79f48_row5_col5,#T_79f48_row6_col6,#T_79f48_row7_col7,#T_79f48_row8_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_79f48_row0_col1{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_79f48_row0_col2{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_79f48_row0_col3{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_79f48_row0_col4,#T_79f48_row6_col8{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_79f48_row0_col5,#T_79f48_row2_col1,#T_79f48_row3_col1,#T_79f48_row4_col2{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_79f48_row0_col6,#T_79f48_row2_col4,#T_79f48_row2_col6,#T_79f48_row2_col8,#T_79f48_row5_col7,#T_79f48_row6_col0,#T_79f48_row6_col1,#T_79f48_row6_col2,#T_79f48_row6_col3,#T_79f48_row7_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_79f48_row0_col7,#T_79f48_row1_col4{
#             background-color:  #62a2cb;
#             color:  #000000;
#         }#T_79f48_row0_col8,#T_79f48_row3_col6{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_79f48_row1_col0{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_79f48_row1_col2{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_79f48_row1_col3,#T_79f48_row2_col3{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_79f48_row1_col5,#T_79f48_row4_col5{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_79f48_row1_col6,#T_79f48_row5_col4{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_79f48_row1_col7{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_79f48_row1_col8{
#             background-color:  #9fbad9;
#             color:  #000000;
#         }#T_79f48_row2_col0,#T_79f48_row5_col2{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_79f48_row2_col5,#T_79f48_row8_col0{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_79f48_row2_col7{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_79f48_row3_col0,#T_79f48_row5_col8,#T_79f48_row8_col2{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_79f48_row3_col2,#T_79f48_row8_col4{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_79f48_row3_col4{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_79f48_row3_col5{
#             background-color:  #308cbe;
#             color:  #000000;
#         }#T_79f48_row3_col7,#T_79f48_row7_col1{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_79f48_row3_col8{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_79f48_row4_col0,#T_79f48_row5_col1{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_79f48_row4_col1{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_79f48_row4_col3,#T_79f48_row7_col8{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_79f48_row4_col6,#T_79f48_row5_col0,#T_79f48_row6_col5,#T_79f48_row7_col4{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_79f48_row4_col7{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_79f48_row4_col8,#T_79f48_row5_col6,#T_79f48_row8_col3{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_79f48_row5_col3{
#             background-color:  #4094c3;
#             color:  #000000;
#         }#T_79f48_row6_col4{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_79f48_row6_col7{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_79f48_row7_col0{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_79f48_row7_col2{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_79f48_row7_col3{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_79f48_row7_col6{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_79f48_row8_col1{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_79f48_row8_col5{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_79f48_row8_col6{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_79f48_row8_col7{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }</style><table id="T_79f48_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pregnancies</th>        <th class="col_heading level0 col1" >Glucose</th>        <th class="col_heading level0 col2" >BloodPressure</th>        <th class="col_heading level0 col3" >SkinThickness</th>        <th class="col_heading level0 col4" >Insulin</th>        <th class="col_heading level0 col5" >BMI</th>        <th class="col_heading level0 col6" >DiabetesPedigreeFunction</th>        <th class="col_heading level0 col7" >Age</th>        <th class="col_heading level0 col8" >Outcome</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_79f48_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#                         <td id="T_79f48_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_79f48_row0_col1" class="data row0 col1" >0.166329</td>
#                         <td id="T_79f48_row0_col2" class="data row0 col2" >0.285013</td>
#                         <td id="T_79f48_row0_col3" class="data row0 col3" >0.167298</td>
#                         <td id="T_79f48_row0_col4" class="data row0 col4" >0.104081</td>
#                         <td id="T_79f48_row0_col5" class="data row0 col5" >0.128207</td>
#                         <td id="T_79f48_row0_col6" class="data row0 col6" >-0.006459</td>
#                         <td id="T_79f48_row0_col7" class="data row0 col7" >0.550525</td>
#                         <td id="T_79f48_row0_col8" class="data row0 col8" >0.268218</td>
#             </tr>
#             <tr>
#                         <th id="T_79f48_level0_row1" class="row_heading level0 row1" >Glucose</th>
#                         <td id="T_79f48_row1_col0" class="data row1 col0" >0.166329</td>
#                         <td id="T_79f48_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_79f48_row1_col2" class="data row1 col2" >0.223192</td>
#                         <td id="T_79f48_row1_col3" class="data row1 col3" >0.228043</td>
#                         <td id="T_79f48_row1_col4" class="data row1 col4" >0.581186</td>
#                         <td id="T_79f48_row1_col5" class="data row1 col5" >0.232771</td>
#                         <td id="T_79f48_row1_col6" class="data row1 col6" >0.137246</td>
#                         <td id="T_79f48_row1_col7" class="data row1 col7" >0.267136</td>
#                         <td id="T_79f48_row1_col8" class="data row1 col8" >0.494650</td>
#             </tr>
#             <tr>
#                         <th id="T_79f48_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#                         <td id="T_79f48_row2_col0" class="data row2 col0" >0.285013</td>
#                         <td id="T_79f48_row2_col1" class="data row2 col1" >0.223192</td>
#                         <td id="T_79f48_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_79f48_row2_col3" class="data row2 col3" >0.226839</td>
#                         <td id="T_79f48_row2_col4" class="data row2 col4" >0.098272</td>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_corr_1, annot=True, vmax=1, vmin=-1, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
# Outcome 수치에 대한 상관계수만 모아서 보기

df_corr["Outcome"]
# Out:
# Pregnancies                 0.268218
# Glucose                     0.494650
# BloodPressure               0.170589
# SkinThickness               0.259491
# Insulin                     0.303454
# BMI                         0.313680
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# ### 상관계수가 높은 변수끼리 보기

# %%
# Insulin 과 Glucose 로 regplot 그리기
sns.regplot(data=df_matrix, x="Insulin", y="Glucose")
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Glucose'>

# %%
# Age 와 Pregnancies 로 regplot 그리기
sns.regplot(data=df_matrix, x="Age", y="Pregnancies")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pregnancies'>

# %%
# Age 와 Pregnancies 로 lmplot 을 그리고 Outcome 에 따라 다른 색상으로 표현
sns.lmplot(data=df, x="Age", y="Pregnancies",
          hue="Outcome", col="Outcome")
